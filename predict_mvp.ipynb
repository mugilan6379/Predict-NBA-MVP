# %%
import pandas as pd

# %%
mvp = pd.read_csv('player_mvp_stats.csv')
mvp.head()
# Out:
#    Unnamed: 0          Player Pos  Age   Tm   G  GS    MP   FG   FGA  ...  \
# 0           0      A.C. Green  PF   27  LAL  82  21  26.4  3.1   6.6  ...
# 1           1     Byron Scott  SG   29  LAL  82  82  32.1  6.1  12.8  ...
# 2           2  Elden Campbell  PF   22  LAL  52   0   7.3  1.1   2.4  ...
# 3           3   Irving Thomas  PF   25  LAL  26   0   4.2  0.7   1.9  ...
# 4           4    James Worthy  SF   29  LAL  78  74  38.6  9.2  18.7  ...
#
#    Pts Max  Share                Team   W   L   W/L%   GB   PS/G  PA/G   SRS
# 0      0.0    0.0  Los Angeles Lakers  58  24  0.707  5.0  106.3  99.6  6.73
# 1      0.0    0.0  Los Angeles Lakers  58  24  0.707  5.0  106.3  99.6  6.73
# 2      0.0    0.0  Los Angeles Lakers  58  24  0.707  5.0  106.3  99.6  6.73
# 3      0.0    0.0  Los Angeles Lakers  58  24  0.707  5.0  106.3  99.6  6.73
# 4      0.0    0.0  Los Angeles Lakers  58  24  0.707  5.0  106.3  99.6  6.73
#
# [5 rows x 42 columns]

# %%
del mvp['Unnamed: 0']

# %%
mvp.isnull().sum()
# Out:
# Player        0
# Pos           0
# Age           0
# Tm            0
# G             0
# GS            0
# MP            0
# FG            0
# FGA           0
# FG%          50
# 3P            0
# 3PA           0
# 3P%        2042
# 2P            0
# 2PA           0
# 2P%          84
# eFG%         50
# FT            0
# FTA           0
# FT%         462
# ORB           0
# DRB           0
# TRB           0
# AST           0
# STL           0
# BLK           0
# TOV           0
# PF            0
# PTS           0
# Year          0
# Pts Won       0
# Pts Max       0
# Share         0
# Team          0
# W             0
# L             0
# W/L%          0
# GB            0
# PS/G          0
# PA/G          0
# SRS           0
# dtype: int64

# %%
mvp[mvp['3P%'].isnull()][['Player','3PA']]
# Out:
#                  Player  3PA
# 2        Elden Campbell  0.0
# 3         Irving Thomas  0.0
# 18           Jack Haley  0.0
# 20          Keith Owens  0.0
# 30      Benoit Benjamin  0.0
# ...                 ...  ...
# 14061    Evan Eschmeyer  0.0
# 14062  Gheorghe Mureșan  0.0
# 14064     Jim McIlvaine  0.0
# 14070  Mark Hendrickson  0.0
# 14071      Michael Cage  0.0
#
# [2042 rows x 2 columns]

# %%
mvp=mvp.fillna(0)
